# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
X, y = make_circles(15000, noise=0.04, random_state=42)
X
# Out:
# array([[-0.791265  , -0.11993781],
#        [ 0.65942603, -0.72849579],
#        [ 0.06939808, -0.7839774 ],
#        ...,
#        [-0.20948612, -0.91566117],
#        [ 0.72041292,  0.68990366],
#        [ 0.91123779, -0.22257126]])

# %%
circles = pd.DataFrame({"X0":X[:,0],"X1":X[:,1], "label":y})
circles
# Out:
#              X0        X1  label
# 0     -0.791265 -0.119938      1
# 1      0.659426 -0.728496      0
# 2      0.069398 -0.783977      1
# 3      0.711577  0.606883      0
# 4      0.290970 -0.965372      0
# ...         ...       ...    ...
# 14995 -0.371576 -0.958663      0
# 14996  0.179634 -0.753407      1
# 14997 -0.209486 -0.915661      0
# 14998  0.720413  0.689904      0
# 14999  0.911238 -0.222571      0
#
# [15000 rows x 3 columns]

# %%
plt.scatter(circles["X0"], circles["X1"], c=y, cmap=plt.cm.RdYlBu)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, circles["label"], test_size=0.3, random_state=42)
print({"X_train.shape":X_train.shape}, {"X_test.shape":X_test.shape})
# Out:
# {'X_train.shape': (10500, 2)} {'X_test.shape': (4500, 2)}

# %%
X_train.shape, X_test.shape
# Out:
# ((10500, 2), (4500, 2))

# %%
tf.random.set_seed(42)
# creat the model
overfit_model = tf.keras.Sequential([
    tf.keras.layers.Dense(30, activation="relu"),
    tf.keras.layers.Dense(20, activation="relu"),
    tf.keras.layers.Dense(10, activation="sigmoid"),
    tf.keras.layers.Dense(1)
])

# compile the model
overfit_model.compile(loss=tf.keras.losses.binary_focal_crossentropy,
                      optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
                      metrics=tf.keras.metrics.binary_focal_crossentropy)

# %%
tf.random.set_seed(42)
# fit the model
history = overfit_model.fit(X_train, y_train, epochs=30, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/30
# 296/296 [==============================] - 3s 3ms/step - loss: 0.0856 - binary_focal_crossentropy: 0.0856 - val_loss: 0.0120 - val_binary_focal_crossentropy: 0.0120
# Epoch 2/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0155 - binary_focal_crossentropy: 0.0155 - val_loss: 0.0173 - val_binary_focal_crossentropy: 0.0173
# Epoch 3/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0362 - binary_focal_crossentropy: 0.0362 - val_loss: 0.0510 - val_binary_focal_crossentropy: 0.0510
# Epoch 4/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0128 - binary_focal_crossentropy: 0.0128 - val_loss: 0.0083 - val_binary_focal_crossentropy: 0.0083
# Epoch 5/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0105 - binary_focal_crossentropy: 0.0105 - val_loss: 0.0107 - val_binary_focal_crossentropy: 0.0107
# Epoch 6/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.2671 - binary_focal_crossentropy: 0.2671 - val_loss: 0.0354 - val_binary_focal_crossentropy: 0.0354
# Epoch 7/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0237 - binary_focal_crossentropy: 0.0237 - val_loss: 0.0214 - val_binary_focal_crossentropy: 0.0214
# Epoch 8/30
# 296/296 [==============================] - 1s 4ms/step - loss: 0.0212 - binary_focal_crossentropy: 0.0212 - val_loss: 0.0198 - val_binary_focal_crossentropy: 0.0198
# Epoch 9/30
# 296/296 [==============================] - 1s 4ms/step - loss: 0.0194 - binary_focal_crossentropy: 0.0194 - val_loss: 0.0180 - val_binary_focal_crossentropy: 0.0180
# Epoch 10/30
# 296/296 [==============================] - 1s 4ms/step - loss: 0.0175 - binary_focal_crossentropy: 0.0175 - val_loss: 0.0164 - val_binary_focal_crossentropy: 0.0164
# Epoch 11/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0160 - binary_focal_crossentropy: 0.0160 - val_loss: 0.0148 - val_binary_focal_crossentropy: 0.0148
# Epoch 12/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0142 - binary_focal_crossentropy: 0.0142 - val_loss: 0.0131 - val_binary_focal_crossentropy: 0.0131
# Epoch 13/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0131 - binary_focal_crossentropy: 0.0131 - val_loss: 0.0121 - val_binary_focal_crossentropy: 0.0121
# Epoch 14/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0121 - binary_focal_crossentropy: 0.0121 - val_loss: 0.0106 - val_binary_focal_crossentropy: 0.0106
# Epoch 15/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0104 - binary_focal_crossentropy: 0.0104 - val_loss: 0.0092 - val_binary_focal_crossentropy: 0.0092
# Epoch 16/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0086 - binary_focal_crossentropy: 0.0086 - val_loss: 0.0073 - val_binary_focal_crossentropy: 0.0073
# Epoch 17/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0080 - binary_focal_crossentropy: 0.0080 - val_loss: 0.0065 - val_binary_focal_crossentropy: 0.0065
# Epoch 18/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0069 - binary_focal_crossentropy: 0.0069 - val_loss: 0.0067 - val_binary_focal_crossentropy: 0.0067
# Epoch 19/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0115 - binary_focal_crossentropy: 0.0115 - val_loss: 0.0063 - val_binary_focal_crossentropy: 0.0063
# Epoch 20/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0067 - binary_focal_crossentropy: 0.0067 - val_loss: 0.0072 - val_binary_focal_crossentropy: 0.0072
# Epoch 21/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0065 - binary_focal_crossentropy: 0.0065 - val_loss: 0.0576 - val_binary_focal_crossentropy: 0.0576
# Epoch 22/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0168 - binary_focal_crossentropy: 0.0168 - val_loss: 0.0064 - val_binary_focal_crossentropy: 0.0064
# Epoch 23/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0066 - binary_focal_crossentropy: 0.0066 - val_loss: 0.0509 - val_binary_focal_crossentropy: 0.0509
# Epoch 24/30
# 296/296 [==============================] - 1s 4ms/step - loss: 0.0091 - binary_focal_crossentropy: 0.0091 - val_loss: 0.0204 - val_binary_focal_crossentropy: 0.0204
# Epoch 25/30
# 296/296 [==============================] - 1s 4ms/step - loss: 0.0061 - binary_focal_crossentropy: 0.0061 - val_loss: 0.0201 - val_binary_focal_crossentropy: 0.0201
# Epoch 26/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0129 - binary_focal_crossentropy: 0.0129 - val_loss: 0.0079 - val_binary_focal_crossentropy: 0.0079
# Epoch 27/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0058 - binary_focal_crossentropy: 0.0058 - val_loss: 0.0063 - val_binary_focal_crossentropy: 0.0063
# Epoch 28/30
# 296/296 [==============================] - 1s 2ms/step - loss: 0.0059 - binary_focal_crossentropy: 0.0059 - val_loss: 0.0093 - val_binary_focal_crossentropy: 0.0093
# Epoch 29/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0060 - binary_focal_crossentropy: 0.0060 - val_loss: 0.0227 - val_binary_focal_crossentropy: 0.0227
# Epoch 30/30
# 296/296 [==============================] - 1s 3ms/step - loss: 0.0059 - binary_focal_crossentropy: 0.0059 - val_loss: 0.0065 - val_binary_focal_crossentropy: 0.0065

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
overfit_model.evaluate(X_test, y_test)
# Out:
# 141/141 [==============================] - 0s 2ms/step - loss: 0.0049 - binary_focal_crossentropy: 0.0049
# [0.004926620051264763, 0.004926620051264763]

# %%
y_predic = overfit_model.predict(X_test)
# Out:
# 141/141 [==============================] - 0s 1ms/step

# %%
y_predicted = []

for i in y_predic:
  if i >=0.5:
    y_predicted.append(1)
  else:
    y_predicted.append(0)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
cm = confusion_matrix(y_test, y_predicted)
plt.figure(figsize=(8,5))
sn.heatmap(cm, fmt="d", annot=None)
cm
# Out:
# array([[2235,    8],
#        [  22, 2235]])
